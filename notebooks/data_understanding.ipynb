# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 


df = pd.read_csv('abm.csv')
display(df)
# Out:
#      casenum  year  month   age   race     sex   dx  priordx  priorrx  \
# 0          1  78.0    1.0   4.0  black  female  1.0      0.0      0.0
# 1          2  78.0   12.0   1.0  black    male  1.0      0.0      0.0
# 2          3  78.0    3.0   0.8  black    male  0.0      1.0      1.0
# 3          4  78.0    8.0  54.0  black    male  6.0      2.0      0.0
# 4          5   NaN    NaN   NaN    NaN     NaN  NaN      NaN      NaN
# ..       ...   ...    ...   ...    ...     ...  ...      ...      ...
# 576      577  70.0    7.0   2.0  black  female  3.0      0.0      0.0
# 577      578  70.0    7.0  23.0  black    male  4.0      0.0      0.0
# 578      579  70.0    8.0   8.0  black    male  4.0      0.0      0.0
# 579      580  70.0    7.0   1.0  black  female  0.0      0.0      1.0
# 580      581  70.0    7.0  13.0  white    male  6.0      2.0      1.0
#
#            wbc  ...   pr2  reds2  whites2  polys2  lymphs2  monos2  others2  \
# 0     6.500000  ...  46.0    1.0     47.0     0.0    100.0     0.0      0.0
# 1     3.700000  ...   NaN    NaN      NaN     NaN      NaN     NaN      NaN
# 2          NaN  ...  51.0  335.0    230.0     0.0    100.0     0.0      0.0
# 3     7.500000  ...   NaN    NaN      NaN     NaN      NaN     NaN      NaN
# 4          NaN  ...   NaN    NaN      NaN     NaN      NaN     NaN      NaN
# ..         ...  ...   ...    ...      ...     ...      ...     ...      ...
# 576   4.900000  ...   NaN    NaN      6.0     0.0    100.0     0.0      0.0
# 577  10.599999  ...   NaN    0.0    332.0     0.0    100.0     0.0      0.0
# 578  15.099999  ...   NaN    NaN     28.0     0.0    100.0     0.0      0.0
# 579  11.599999  ...  22.0    NaN      5.0     0.0    100.0     0.0      0.0
# 580  12.500000  ...   NaN    2.0      0.0     NaN      NaN     NaN      NaN
#
#      sumbands    subset  abm
# 0    2.000000      test  1.0
# 1    3.099000  training  1.0
# 2         NaN      test  NaN
# 3    5.108999  training  1.0
# 4         NaN      test  0.0
# ..        ...       ...  ...
# 576       NaN      test  1.0
# 577       NaN  training  0.0
# 578       NaN      test  0.0
# 579       NaN  training  NaN
# 580       NaN      test  1.0
#
# [581 rows x 43 columns]

# %%
# Data integrity exploration 

# check the rows and columns 
print('the shape of dataset')
print(df.shape)

# check for any missing values 
print('Missing data')
miss = df.isna().sum()
miss = miss[miss > 0].sum()
print(miss)

df.info()
# Out:
# the shape of dataset
# (581, 43)
# Missing data
# 10174
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581 entries, 0 to 580
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   casenum   581 non-null    int64
#  1   year      509 non-null    float64
#  2   month     500 non-null    float64
#  3   age       500 non-null    float64
#  4   race      496 non-null    object
#  5   sex       500 non-null    object
#  6   dx        498 non-null    float64
#  7   priordx   468 non-null    float64
#  8   priorrx   473 non-null    float64
#  9   wbc       440 non-null    float64
#  10  pmn       435 non-null    float64
#  11  bands     428 non-null    float64
#  12  compns    286 non-null    float64
#  13  daysrx    260 non-null    float64
#  14  offrx     172 non-null    float64
#  15  lptodc    167 non-null    float64
#  16  lpgap     143 non-null    float64
#  17  morelabs  98 non-null     float64
#  18  bloodgl   323 non-null    float64
#  19  gl        452 non-null    float64
#  20  pr        332 non-null    float64
#  21  reds      310 non-null    float64
#  22  whites    480 non-null    float64
#  23  polys     449 non-null    float64
#  24  lymphs    419 non-null    float64
#  25  monos     416 non-null    float64
#  26  others    417 non-null    float64
#  27  gram      268 non-null    float64
#  28  culture   274 non-null    float64
#  29  cie       72 non-null     float64
#  30  bloodclt  147 non-null    float64
#  31  bloodgl2  122 non-null    float64
#  32  gl2       268 non-null    float64
#  33  pr2       223 non-null    float64
#  34  reds2     250 non-null    float64
#  35  whites2   307 non-null    float64
#  36  polys2    276 non-null    float64
#  37  lymphs2   271 non-null    float64
#  38  monos2    267 non-null    float64
#  39  others2   265 non-null    float64
#  40  sumbands  165 non-null    float64
#  41  subset    581 non-null    object
#  42  abm       501 non-null    float64
# dtypes: float64(39), int64(1), object(3)
# memory usage: 195.3+ KB
