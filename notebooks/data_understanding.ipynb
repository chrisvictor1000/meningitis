# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 


df = pd.read_csv('../data/meningitis.csv')
df = df.drop('casenum', axis=1)
display(df)
# Out:
#      year  month   age   race     sex   dx  priordx  priorrx        wbc   pmn  \
# 0    78.0    1.0   4.0  black  female  1.0      0.0      0.0   6.500000  50.0
# 1    78.0   12.0   1.0  black    male  1.0      0.0      0.0   3.700000  62.0
# 2    78.0    3.0   0.8  black    male  0.0      1.0      1.0        NaN   NaN
# 3    78.0    8.0  54.0  black    male  6.0      2.0      0.0   7.500000  73.0
# 4     NaN    NaN   NaN    NaN     NaN  NaN      NaN      NaN        NaN   NaN
# ..    ...    ...   ...    ...     ...  ...      ...      ...        ...   ...
# 576  70.0    7.0   2.0  black  female  3.0      0.0      0.0   4.900000  57.0
# 577  70.0    7.0  23.0  black    male  4.0      0.0      0.0  10.599999  70.0
# 578  70.0    8.0   8.0  black    male  4.0      0.0      0.0  15.099999  91.0
# 579  70.0    7.0   1.0  black  female  0.0      0.0      1.0  11.599999  53.0
# 580  70.0    7.0  13.0  white    male  6.0      2.0      1.0  12.500000  77.0
#
# ...

# %%
# exploring the variables 

for p in df.columns.tolist():
    print(p)
# Out:
# year
# month
# age
# race
# sex
# dx
# priordx
# priorrx
# wbc
# pmn
# bands
# compns
# daysrx
# offrx
# lptodc
# lpgap
# morelabs
# bloodgl
# gl
# pr
# reds
# whites
# polys
# lymphs
# monos
# others
# gram
# culture
# cie
# bloodclt
# bloodgl2
# gl2
# pr2
# reds2
# whites2
# polys2
# lymphs2
# monos2
# others2
# sumbands
# subset
# abm

# %%
df['sumbands']
# Out:
# 0      2.000000
# 1      3.099000
# 2           NaN
# 3      5.108999
# 4           NaN
#          ...
# 576         NaN
# 577         NaN
# 578         NaN
# 579         NaN
# 580         NaN
# Name: sumbands, Length: 581, dtype: float64

# %% [markdown]
# # columns to change
#
# - priorrx -> prior_atbx
# - priordx -> prior_dx
# - compns -> complications
# - daysrx -> trt_dur_days
# - gl -> csf_gl
# - pr -> csf_pr
# - reds -> csf_rbc
# - whites -> csf_wbc
# - lymphs -> csf_lymphs
# - monos -> csf_monos
# - polys -> csf_polys
# - others -> csf_others
# - pr2 -> csf_pr2
# - reds -> csf_rbc2
# -  whites2 -> csf_wbc2
# - polys2 -> csf_polys2
# - monos2 -> csf_monos2
# - others -> csf_others2
# -
#
# ### COlumns not use because we dont know what they are
# - lptodc
# - culture -> because our goal is to use what we have before
# - subset to original training or test set as defined as original researchers
